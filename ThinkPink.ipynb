# %% [markdown]
# # **ML Project "ThinkPink" / challenge1**

# %% [markdown]
# # **Load DATA**

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/Maryyaaaa/ThinkPink/refs/heads/main/train.csv')
df
print(df.head())
# Out:
#    id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0   1         M       11.840         18.70           77.93      440.6
# 1   2         B       12.760         18.84           81.87      496.6
# 2   3         M       23.290         26.67          158.90     1685.0
# 3   4         B       12.560         19.07           81.92      485.8
# 4   5         B        9.742         15.67           61.50      289.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11090           0.15160         0.12180              0.05182
# 1          0.09676           0.07952         0.02688              0.01781
# 2          0.11410           0.20840         0.35230              0.16200
# 3          0.08760           0.10380         0.10300              0.04391
# 4          0.09037           0.04689         0.01103              0.01407
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         16.82          28.12           119.40       888.7
# 1  ...         13.75          25.99            87.82       579.7
# 2  ...         25.12          32.68           177.00      1986.0
# 3  ...         13.37          22.43            89.02       547.4
# 4  ...         10.75          20.88            68.09       355.2
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1637             0.5775          0.69560               0.15460
# 1            0.1298             0.1839          0.12550               0.08312
# 2            0.1536             0.4167          0.78920               0.27330
# 3            0.1096             0.2002          0.23880               0.09265
# 4            0.1467             0.0937          0.04043               0.05159
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4761                  0.14020
# 1          0.2744                  0.07238
# 2          0.3198                  0.08762
# 3          0.2121                  0.07188
# 4          0.2841                  0.08175
#
# [5 rows x 32 columns]

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# ### **Data Serparation into X and Y**

# %%
y = df['diagnosis']
y
# Out:
# 0      M
# 1      B
# 2      M
# 3      B
# 4      B
#       ..
# 395    M
# 396    B
# 397    B
# 398    M
# 399    B
# Name: diagnosis, Length: 400, dtype: object

# %%
x= df.drop('diagnosis', axis=1)
x
# Out:
#       id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      1       11.840         18.70           77.93      440.6
# 1      2       12.760         18.84           81.87      496.6
# 2      3       23.290         26.67          158.90     1685.0
# 3      4       12.560         19.07           81.92      485.8
# 4      5        9.742         15.67           61.50      289.9
# ..   ...          ...           ...             ...        ...
# 395  396       14.220         23.12           94.37      609.9
# 396  397       11.800         17.26           75.26      431.9
# 397  398       12.800         17.46           83.05      508.3
# 398  399       14.190         23.81           92.87      610.7
# 399  400       12.990         14.23           84.08      514.3
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11090           0.15160         0.12180              0.05182
# 1            0.09676           0.07952         0.02688              0.01781
# 2            0.11410           0.20840         0.35230              0.16200
# 3            0.08760           0.10380         0.10300              0.04391
# 4            0.09037           0.04689         0.01103              0.01407
# ..               ...               ...             ...                  ...
# 395          0.10750           0.24130         0.19810              0.06618
# 396          0.09087           0.06232         0.02853              0.01638
# 397          0.08044           0.08895         0.07390              0.04083
# 398          0.09463           0.13060         0.11150              0.06462
# 399          0.09462           0.09965         0.03738              0.02098
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0           0.2301  ...         16.82          28.12           119.40
# 1           0.1759  ...         13.75          25.99            87.82
# 2           0.2200  ...         25.12          32.68           177.00
# 3           0.1533  ...         13.37          22.43            89.02
# 4           0.2081  ...         10.75          20.88            68.09
# ..             ...  ...           ...            ...              ...
# 395         0.2384  ...         15.74          37.18           106.40
# 396         0.1847  ...         13.45          24.49            86.00
# 397         0.1574  ...         13.74          21.06            90.72
# 398         0.2235  ...         16.86          34.85           115.00
# 399         0.1652  ...         13.72          16.91            87.38
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0         888.7           0.16370             0.5775          0.69560
# 1         579.7           0.12980             0.1839          0.12550
# 2        1986.0           0.15360             0.4167          0.78920
# 3         547.4           0.10960             0.2002          0.23880
# 4         355.2           0.14670             0.0937          0.04043
# ..          ...               ...                ...              ...
# 395       762.4           0.15330             0.9327          0.84880
# 396       562.0           0.12440             0.1726          0.14490
# 397       591.0           0.09534             0.1812          0.19010
# 398       811.3           0.15590             0.4059          0.37440
# 399       576.0           0.11420             0.1975          0.14500
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                 0.15460          0.4761                  0.14020
# 1                 0.08312          0.2744                  0.07238
# 2                 0.27330          0.3198                  0.08762
# 3                 0.09265          0.2121                  0.07188
# 4                 0.05159          0.2841                  0.08175
# ..                    ...             ...                      ...
# 395               0.17720          0.5166                  0.14460
# 396               0.05356          0.2779                  0.08121
# 397               0.08296          0.1988                  0.07053
# 398               0.17720          0.4724                  0.10260
# 399               0.05850          0.2432                  0.10090
#
# [400 rows x 31 columns]

# %% [markdown]
# ## **Spliting The Data into training and validation sets**

# %%
from sklearn.model_selection import train_test_split

x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=100)

# %% [markdown]
# # **Model Building**

# %% [markdown]
# ## **Scalling The Data**

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_val_scaled = scaler.transform(x_val)

# %% [markdown]
# ## **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=500)
model.fit(x_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=500)

# %% [markdown]
# ## **Evaluate the model's performance on the validation set**

# %%
accuracy = model.score(x_val_scaled, y_val)
print(f"Validation accuracy: {accuracy * 100:.2f}%")
# Out:
# Validation accuracy: 98.75%
